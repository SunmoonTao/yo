# %% [markdown]
# # 0. Install packages

# %%
pip install dendropy
# Out:
# Collecting dendropy
#   Downloading DendroPy-4.5.2.tar.gz (15.2 MB)
#      |████████████████████████████████| 15.2 MB 14.2 MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /Users/taol9/opt/anaconda3/envs/ete3/lib/python3.6/site-packages (from dendropy) (58.0.4)
# Building wheels for collected packages: dendropy
#   Building wheel for dendropy (setup.py) ... done
#   Created wheel for dendropy: filename=DendroPy-4.5.2-py3-none-any.whl size=453171 sha256=454518a55b7082c9f3b060f2a87ba3b6495c9e3f876e3c377c5d5299c078f256
#   Stored in directory: /Users/taol9/Library/Caches/pip/wheels/92/47/66/355ad37463381c8165ef0bedd1222354dfce2dcf3684d47977
# Successfully built dendropy
# Installing collected packages: dendropy
# Successfully installed dendropy-4.5.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import PyQt5
import ete3
from ete3 import Tree, PhyloTree,TreeStyle, NodeStyle, faces, AttrFace, CircleFace, TextFace
import dendropy

# %%
#testing ete3

# %%
t = Tree()
t.populate(10)
ts = TreeStyle()
ts.show_leaf_name = True
ts.show_branch_length = True
ts.show_branch_support = True
t.show(tree_style=ts)

# %% [markdown]
# # Def Fun

# %%
def unroot_FastTree_tree(newick_output_file):
    rooted_tree = dendropy.Tree.get_from_path(newick_output_file, "newick")
    rooted_tree.reroot_at_node(rooted_tree.find_node_with_taxon_label('root'), update_bipartitions=False)
    tree = dendropy.Tree.get_from_string(rooted_tree.as_string('newick', suppress_rooting=False).replace('root', ''), 'newick')
    tree.ladderize(ascending=False)
    return tree

# %% [markdown]
# # go to working dir

# %%
cd /Users/taol9/Documents/CRC/Melanie/
# Out:
# /Users/taol9/Documents/CRC/Melanie

# %%
ls
# Out:
# 221027_AKPS organoids in vitro_overview.xlsx
# edits.xlsx
# edits_mips.xlsx
# mcrcr1.nw
# opoolsentrysample.xlsx
# sunrise_results_analysis_7498.tsv
# ~$221027_AKPS organoids in vitro_overview.xlsx
# ~$edits_mips.xlsx

# %% [markdown]
# # plot

# %%
#HCT116
# generation_map={"A":"1","B":"11","C":'111','D':'112','E':'12','F':'121','G':'122',"H":'2'}
# def generation(well,generation_map):
#     row= well[9]
#     return generation_map[row]

# %%
#mcrcr1
generation_map={}
for i in range(12):
    if i+1 in [1,2]:
        generation_map[i+1]='11'
    elif i+1 in [3,4]:
        generation_map[i+1]='12'
    elif i+1 in [5,6]:
        generation_map[i+1]='31'
    elif i+1 in [7,8]:
        generation_map[i+1]='32'
    elif i+1 in [9,10]:
        generation_map[i+1]='51'
    elif i+1 in [11,12]:
        generation_map[i+1]='52'
def generation(well,generation_map):
    row= int(well.split('_')[1][1:])
    return generation_map[row]

# %% [markdown]
# ## basic plot

# %%
x=unroot_FastTree_tree("mcrcr1.1000.nw")
t=Tree(x.as_string(schema='newick')[5:])

for leaf in t:
    try:
#         leaf.name = generation(leaf.name, generation_map)
        leaf.name = generation(leaf.name, generation_map)+"___"+leaf.name

    except:
        continue
print(t)
# Out:
#                               /-52___mCRCR1_G12_S95
#                            /-|
#                         /-|   \-12___mCRCR1_G4_S31
#                        |  |
#                      /-|   \-31___mCRCR1_G6_S47
#                     |  |
#                     |  |   /-31___mCRCR1_G5_S39
#                   /-|   \-|
#                  |  |      \-32___mCRCR1_C8_S59
#                  |  |
#                  |  |   /-32___mCRCR1_G7_S55
#                /-|   \-|
#               |  |      \-51___mCRCR1_H10_S80
#               |  |
#               |  |      /-51___mCRCR1_A10_S73
#               |  |   /-|
#             /-|   \-|   \-52___mCRCR1_H11_S88
#            |  |     |
#            |  |      \-32___mCRCR1_G8_S63
#            |  |
#            |  |   /-52___mCRCR1_A11_S81
#            |   \-|
#            |      \-51___mCRCR1_G10_S79
#          /-|
#         |  |            /-32___mCRCR1_A8_S57
#         |  |         /-|
#         |  |      /-|   \-51___mCRCR1_G9_S71
#         |  |     |  |
#         |  |   /-|   \-52___mCRCR1_C11_S83
#       /-|  |  |  |
#      |  |  |  |  |   /-52___mCRCR1_B12_S90
#      |  |   \-|   \-|
#      |  |     |      \-12___mCRCR1_G3_S23
#    /-|  |     |
#   |  |  |      \-52___mCRCR1_G11_S87
#   |  |  |
# --|  |   \-11___mCRCR1_E1_S5
#   |  |
#   |   \-11___mCRCR1_A1_S1
#   |
#    \-11___mCRCR1_G2_S15

# %% [markdown]
# ## 2 stylish ploting

# %%
x=unroot_FastTree_tree("mcrcr1.1000.nw")
t=Tree(x.as_string(schema='newick')[5:])

for leaf in t:
    try:
        leaf.name = generation(leaf.name, generation_map)
#         leaf.name = generation(leaf.name, generation_map)+":"+leaf.name+":"+str(loci_sum[leaf.name])

    except:
        continue
circular_style = TreeStyle()
circular_style.mode = "c" # draw tree in circular mode
circular_style.scale = 20
t.render("circle.tree.png", w=183, units="mm", tree_style=circular_style)
# Out:
# {'nodes': [[315.1317441364751,
#    304.09072390201317,
#    344.57446476170713,
#    333.53344452724514,
#    0,
#    None],
#   [319.9258882092053,
#    286.51880880641386,
#    346.74218025304145,
#    313.33510085025006,
#    1,
#    None],
#   [301.2800221821086,
#    268.94443140002795,
#    326.42704200837983,
#    294.0914512262991,
#    2,
#    None],
#   [225.9740605025377,
#    271.00149315942326,
#    253.64933766129374,
#    298.6767703181793,
#    3,
#    None],
#   [220.31649841738295,
#    379.7522968582135,
#    249.55674900750734,
#    408.99254744833803,
#    4,
#    None],
#   [279.13866335134855,
#    439.9712786051628,
#    304.427936123282,
#    465.26055137709625,
#    5,
#    None],
#   [369.5330492288996,
#    451.58393445717303,
#    396.7777363455336,
#    478.828621573807,
#    6,
#    None],
#   [439.1358447100469,
#    420.6204773936648,
#    468.49877140468175,
#    449.9834040882996,
#    7,
#    None],
#   [488.89676532146586,
#    380.4372135533273,
#    515.8769768920014,
#    407.41742512386287,
#    8,
#    None],
#   [517.2235873445348,
#    343.158516155891,
#    540.9114614768147,
#    366.8463902881707,
#    9,
#    None],
#   [553.7555716736142,
#    313.80056555919754,
#    574.5796367442192,
#    334.6246306298024,
#    10,
#    None],
#   [547.4706841738432,
#    383.8647655667114,
#    573.4961495840616,
#    409.89023097692984,
#    11,
#    None],
#   [496.6529696237084,
#    436.7234072593807,
#    525.5800924918219,
#    465.6505301274942,
#    12,
#    None],
#   [406.5805769946465,
#    476.17984151802534,
#    435.04883040712474,
#    504.6480949305036,
#    13,
#    None],
#   [453.74411861433464,
#    489.4352364390611,
#    483.01675080404823,
#    518.7078686287748,
#    14,
#    None],
#   [393.6287085925499,
#    519.9555132752786,
#    420.6601710014403,
#    546.986975684169,
#    15,
#    None],
#   [301.00970524568135,
#    484.9060377352056,
#    323.2436841854298,
#    507.14001667495404,
#    16,
#    None],
#    386.68479330631476],
#   18: [324.2125980945,
#    324.21259809450004,
#    423.1664729035075,
#    386.68479330631476],
#   19: [324.2125980945,
#    324.21259809450004,
#    350.273915530362,
#    339.8306468974537],
#   20: [324.2125980945,
#    324.21259809450004,
#    343.008399227228,
#    339.8306468974537],
#   21: [324.2125980945,
#    324.21259809450004,
#    421.53698981173267,
#    386.68479330631476],
#   22: [324.2125980945,
#    324.21259809450004,
#    418.04062928637813,
#    386.68479330631476],
#   23: [324.2125980945,
#    324.21259809450004,
#    420.9934817133899,
#    386.68479330631476],
#   24: [324.2125980945,
#    324.21259809450004,
#    349.72936622876574,
#    339.8306468974537],
#   25: [324.2125980945,
#    324.21259809450004,
#    422.46157830086753,
#    386.68479330631476],
#   26: [324.2125980945,
#    324.21259809450004,
#    420.45413842806124,
#    386.68479330631476],
#   27: [324.2125980945,
#    324.21259809450004,
#    344.82425770138474,
#    339.8306468974537],
#   28: [324.2125980945,
#    324.21259809450004,
#    344.80135122980704,
#    339.8306468974537],
#   29: [324.2125980945,
#    324.21259809450004,
#    341.83183955073883,
#    339.8306468974537],
#   30: [324.2125980945,
#    324.21259809450004,
#    343.888215976461,
#    339.8306468974537],
#   31: [324.2125980945,
#    324.21259809450004,
#    423.26955202560697,
#    386.68479330631476],
#   32: [324.2125980945,
#    324.21259809450004,
#    427.2521544703602,
#    386.68479330631476],
#   33: [324.2125980945,
#    324.21259809450004,
#    420.43852037925825,
#    386.68479330631476],
#   34: [324.2125980945,
#    324.21259809450004,
#    346.2569533782424,
#    339.8306468974537],
#   35: [324.2125980945,
#    324.21259809450004,
#    420.83730122536036,
#    386.68479330631476],
#   36: [324.2125980945,
#    324.21259809450004,
#    421.24857651050485,
#    386.68479330631476],
#   37: [324.2125980945,
#    324.21259809450004,
#    421.5182481531691,
#    386.68479330631476],
#   38: [324.2125980945,
#    324.21259809450004,
#    398.99077455978875,
#    386.68479330631476],
#   39: [324.2125980945,
#    324.21259809450004,
#    400.0829967727419,
#    386.68479330631476],
#   40: [324.2125980945,
#    324.21259809450004,
#    399.14903745432537,
#    386.68479330631476]}}

# %%
def nwtree_plot(nw):
    x=unroot_FastTree_tree(nw)
    t=Tree(x.as_string(schema='newick')[5:])
    
    for leaf in t:
        try:
#             leaf.name = generation(leaf.name, generation_map)
            leaf.name = generation(leaf.name, generation_map)+"__"+leaf.name
    
        except:
            continue
    ts = TreeStyle()
    ts.show_leaf_name = True
    ts.rotation = 90
    ts.scale =  240 # 120 pixels per branch length unit
    ts.branch_vertical_margin = 5 # 10 pixels between adjacent branches
    
    # ts.show_branch_length = True
    # ts.show_branch_support = True
    # t.show(tree_style=ts)
    t.render(nw+".png", w=183, units="mm", tree_style=ts)

# %%
ls
# Out:
# 221027_AKPS organoids in vitro_overview.xlsx
# circle.tree.png
# edits.xlsx
# edits_mips.xlsx
# mcrcr1.1000.nw
# mcrcr1.cat.1500.nw
# mcrcr1.cat.2000.nw
# mcrcr1.nw
# opoolsentrysample.xlsx
# sunrise_results_analysis_7498.tsv
# ~$221027_AKPS organoids in vitro_overview.xlsx
# ~$edits_mips.xlsx

# %%
nwtree_plot("mcrcr1.cat.1500.nw")

# %%
nwtree_plot("mcrcr1.cat.2000.nw")

# %%
nwtree_plot("mcrcr1.cat.3000.nw")
